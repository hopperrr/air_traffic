# %% [markdown]
# <a href="https://colab.research.google.com/github/hopperrr/air_traffic/blob/main/air_traffic_flights.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Get traffic for US
#https://opensky-network.org/api/states/all?lamin=30.038&lomin=-125.974&lamax=52.214&lomax=-68.748
#ping it twice to create lines connecting these points to show direction of flights over storms.
# !wget 'https://opensky-network.org/api/states/all?lamin=24.00&lomin=-125.974&lamax=52.214&lomax=-68.748' -O 'flights.json'
#36.829,-103.025  25.080,-84.708
# Out:
# --2022-11-01 23:33:29--  https://opensky-network.org/api/states/all?lamin=24.00&lomin=-125.974&lamax=52.214&lomax=-68.748
# Resolving opensky-network.org (opensky-network.org)... 194.209.200.2
# Connecting to opensky-network.org (opensky-network.org)|194.209.200.2|:443... connected.
# HTTP request sent, awaiting response... 200
# Length: unspecified [application/json]
# Saving to: ‘flights.json’
#
# flights.json            [      <=>           ] 556.40K   351KB/s    in 1.6s
#
# 2022-11-01 23:33:31 (351 KB/s) - ‘flights.json’ saved [569753]

# %%
import json
import pandas as pd
with open('/content/flights.json', 'r') as flights:
  flight_data = json.load(flights)
df = pd.json_normalize(flight_data, record_path='states', meta=['time'])
df
# Out:
#            0         1              2           3           4         5  \
# 0     ad4f1d  N957ES    United States  1667345597  1667345598  -97.7276
# 1     a665aa  FSR511    United States  1667345602  1667345602  -88.4456
# 2     aa9321  UAL20     United States  1667345603  1667345603  -87.1923
# 3     ade18c  AAL1771   United States  1667345603  1667345603  -99.6202
# 4     a3b87f  DAL2244   United States  1667345603  1667345603  -82.1709
# ...      ...       ...            ...         ...         ...       ...
# 4265  c00741  WJA529           Canada  1667345513  1667345513  -89.0467
# 4266  a11d08  N171BL    United States  1667345602  1667345602  -79.2875
# 4267  a12403  UAL2294   United States  1667345602  1667345602  -90.6944
# 4268  a73ed2  N566SP    United States  1667345597  1667345598  -97.1457
# 4269  a05dba  UAL1762   United States  1667345602  1667345602 -104.5440
#
#             6         7      8       9      10     11    12        13    14  \
# ...

# %%
df.iloc[:, [5, 6]]

# %%
gfg_csv_data = df.to_csv('GfG.csv', index = True)
